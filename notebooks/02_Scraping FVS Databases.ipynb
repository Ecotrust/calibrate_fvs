# %%
import pandas as pd
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.notebook import tqdm
import seaborn as sns
from statsmodels.stats.weightstats import DescrStatsW
from matplotlib import pyplot as plt
import glob

# %%
dbs = glob.glob("../models/usfia/fvs_outputs/*.db")
len(dbs)
# Out:
# 400221

# %%
def scrape_sqlite(path_to_db, **kwargs):
    """
    Scrapes a sqlite database, converting it into a dictionary of Pandas DataFrames.

    Args:
        path_to_db (str): path to sqlite database
        **kwargs: optional kwargs to pass to Pandas `read_sql_table`

    Returns:
        res (dict): dictionary with table names as keys and Pandas DataFrames as values.
    """
    conn_str = f"sqlite:///{path_to_db}"
    tables = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table'", conn_str)[
        "name"
    ].values

    res = {t: pd.read_sql_table(t, conn_str, **kwargs) for t in tables}
    return res

# %%
TABLES = ["FVS_Cases", "FVS_CalibStats", "FVS_Summary"]
dfs = {t: [] for t in TABLES}

with ThreadPoolExecutor(128) as executor:
    with tqdm(total=len(dbs)) as pbar:
        jobs = [executor.submit(scrape_sqlite, db) for db in dbs]
        for job in as_completed(jobs):
            res = job.result()
            if res is not None:
                for t in TABLES:
                    if t in res:
                        dfs[t].append(res[t])
            pbar.update()
# Out:
#   0%|          | 0/400221 [00:00<?, ?it/s]

# %%
calib = pd.concat(dfs["FVS_CalibStats"], ignore_index=True)
calib.to_csv("../data/processed/usfia_fvs_calibstats.csv", index=False, header=True)
calib.head()
# Out:
#                                  CaseID                  StandID TreeSize
# 0  973503c6-e24e-4e02-852f-71583ea0b042  00131999080201179000431       LG  \
# 1  973503c6-e24e-4e02-852f-71583ea0b042  00131999080201179000431       SM
# 2  b9257b30-152d-4c89-879c-6c14fdab3f62  00272007130402061203771       LG
# 3  b9257b30-152d-4c89-879c-6c14fdab3f62  00272007130402061203771       LG
# 4  57916b6a-0732-413d-8afc-7de38e3fd2fd  00272016150301137252081       LG
#
#   SpeciesFVS SpeciesPLANTS SpeciesFIA  NumTrees  ScaleFactor  StdErrRatio
# 0         TS          NYBI        694         6     1.266709     0.362172  \
# 1         TS          NYBI        694         5     0.593122          NaN
# 2         QA         POTR5        746        10     0.856385     0.835733
# 3         PB          BEPA        375         5     1.010776     1.109627
# 4         QA         POTR5        746        59     1.175822     0.594758
#
#    WeightToInput  ReadCorMult
# 0       0.842223     1.324072
# 1            NaN     0.593122
# 2       0.711943     0.804316
# 3       0.447708     1.024229
# 4       0.886386     1.200488

# %%
cases = pd.concat(dfs["FVS_Cases"], ignore_index=True)
cases.to_csv("../data/processed/usfia_fvs_cases.csv", index=False, header=True)
cases.head()
# Out:
#                                  CaseID         Stand_CN
# 0  973503c6-e24e-4e02-852f-71583ea0b042  238814838010854  \
# 1  6bb8e698-c8e1-4809-bad7-96964592637f   70334058010538
# 2  a2cec0d0-e9ac-47d3-92cc-5a3290de6b95   51658703020004
# 3  2784b588-125e-4898-a6ca-63c2b75790ed  722469697290487
# 4  b9257b30-152d-4c89-879c-6c14fdab3f62  156002713010661
#
#                    StandID MgmtID RunTitle
# 0  00131999080201179000431   NONE           \
# 1  00232003050505021031941   NONE
# 2  00352005030102057874171   NONE
# 3  00552019090502099204271   NONE
# 4  00272007130402061203771   NONE
#
#                                          KeywordFile  SamplingWt Variant
# 0  /mnt/data/github/calibrate_fvs/models/usfia/ke...  4377.50928      SN  \
# 1  /mnt/data/github/calibrate_fvs/models/usfia/ke...  5646.60547      NE
# 2  /mnt/data/github/calibrate_fvs/models/usfia/ke...  5968.20654      CR
# 3  /mnt/data/github/calibrate_fvs/models/usfia/ke...  2810.74390      LS
# 4  /mnt/data/github/calibrate_fvs/models/usfia/ke...  2203.04810      LS
#
#     Version        RV Groups          RunDateTime
# 0  FS2023.3  20230728         2023-11-20-22:11:13
# 1  FS2023.3  20230728         2023-11-21-05:25:34
# 2  FS2023.3  20230728         2023-11-21-11:57:39
# 3  FS2023.3  20230728         2023-11-22-01:10:48
# 4  FS2023.3  20230728         2023-11-21-08:30:59

# %%
summ = pd.concat(dfs["FVS_Summary"], ignore_index=True)
summ.to_csv("../data/processed/usfia_fvs_summary.csv", index=False, header=True)
summ.head()
# Out:
#                                  CaseID                  StandID  Year  Age
# 0  a2cec0d0-e9ac-47d3-92cc-5a3290de6b95  00352005030102057874171  2010   19  \
# 1  a2cec0d0-e9ac-47d3-92cc-5a3290de6b95  00352005030102057874171  2020   29
# 2  f08436b5-5949-477f-9633-bcd619ff03ad  00062009050906037737111  2009    0
# 3  f08436b5-5949-477f-9633-bcd619ff03ad  00062009050906037737111  2019   10
# 4  5bd108c2-9bed-4133-bbd5-886dff6c40ee  00022016030201261523652  2017  257
#
#     Tpa   BA  SDI  CCF  TopHt       QMD  ...  ATCCF  ATTopHt     ATQMD
# 0  2299   20   71   25      8  1.271596  ...     25        8  1.271596  \
# 1  2269   45  137   49     10  1.901678  ...     49       10  1.901678
# 2     0    0    0    0      0  0.000000  ...      0        0  0.000000
# 3     0    0    0    0      0  0.000000  ...      0        0  0.000000
# 4  3029  142  278  213     64  2.931952  ...    213       64  2.931952
#
#    PrdLen  Acc  Mort       MAI  ForTyp  SizeCls  StkCls
# 0      10    2     0  0.000000     926        3       4
# 1       0    0     0  0.000000     926        3       3
# 2      10    0     0  0.000000     999        5       5
# 3       0    0     0  0.000000     999        5       5
# 4      10   26    11  7.980545     270        1       3
#
# [5 rows x 29 columns]
